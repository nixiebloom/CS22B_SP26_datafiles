# %% [markdown]
# # Project data exploration
# Using a dataset that your group is consider using for the term project, let's do some data exploring of the different features in your dataset and their relationships

# %% [markdown]
# Group name:
# Created by: TEAM MEMBER NAMES
# Last updated: DATE
# Briefly describe your dataset

# %% [markdown]
# Import your data. If you want to mount your Google drive you can use `from google.colab import drive` and `drive.mount('/content/drive')`

# %% [markdown]
# ### Q1: Show the first 5 lines of your data. Is your data format as expected or do you have to take into consideration how to handle data.

# %%
# Your code here . . .

# %% [markdown]
# ### Q2: Are there any missing data? If your data can be brought in as a dataframe, what are the data types for each column and is it what was expected?

# %%
# Your code here . . .

# %% [markdown]
# ### Q3: Filtering data.
# Come up with your own question that requires you to filter out your data based on conditional statement

# %%
# Your code here . . .

# %% [markdown]
# ### Q4: Scatter plot.
# Come up with your own question that requires you to select two variables to explore their relationship. What are your observations based on the output plot?

# %%
# Your code here . . .

# %% [markdown]
# ### Q5: Categorical plot.
# Come up with your own question that explores one of your non-numerical variable (or convert one of your numeric variable to a category) and look at their distribution. What are your observations based on the output plot?

# %% [markdown]
# ### Q6: Challenges
# What are some of the challenges you are currently facing in your project? Are there any particular coding related application or topic that you believe could help you further push your project forward?

# %% [markdown]
# *Your responses here . . .*
